# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create sample data
data = {'Study Hours': [2, 4, 6, 8, 10], 'Test Scores': [70, 85, 90, 95, 100]}
df = pd.DataFrame(data)

# %%
# Calculate correlation coefficient
correlation = df['Study Hours'].corr(df['Test Scores'])

# %%
# Print correlation coefficient
print("Correlation Coefficient:", correlation)
# Out:
# Correlation Coefficient: 0.9615239476408232

# %%
plt.figure(figsize=(8, 6))
plt.scatter(df['Study Hours'], df['Test Scores'])
plt.xlabel('Study Hours')
plt.ylabel('Test Scores')
plt.title('Correlation between Study Hours and Test Scores')
plt.grid(True)
plt.show()
